# %% [markdown]
# # Домашнее задание 3
#
# **Выполнил:** Веселов Илья Николаевич
#
# **На сколько выполнил:** 3

# %% [markdown]
# **Правила игры:**
#
# * возле каждой задачи указано число баллов (в сококупности можно получить 10 баллов)
#
# * хотим чистый, читабельный код, сайты - с user-friendly интерфейсом)
#
# * к каждому заданию должен быть приложен код проекта, выложенный на Github (если вы пользуетесь ScraperAPI или другими ключами, то ключи необходимо убирать)
#
# * Оценивание будет происзодить в первую очередь по функциональности - все ли работает и работает так, как должно (но за полное отсутствие стиля мы будем снижать)
#
# P.S. В данном задании вам не потребуется ScraperAPI :з
#
# **Любые extra-вещи будут оцениваться в плюс как доп баллы**

# %% [markdown]
# ## Задание 1 (3 балла)

# %% [markdown]
# Парсим [Steam](https://store.steampowered.com/) с помощью Scrapy!
#
# Необходимо выбрать 3 запроса (например, "инди", "стратегии", "minecraft", на каждый запрос должно быть минимум 90 результатов), и вытащить по ним:
#
# * Все игры на первых 2 страницах (найдите, каким образом отображаются страницы)
#
# И для каждой игры вытащить:
#
# * Название
#
# * Категорию (весь путь, за исключением Все игры и самого названия игры)
#
# * Число всех обзоров и общая оценка
#
# * Дата выхода
#
# * Разработчик
#
# * Метки (тэги) игры
#
# * Цена
#
# * Доступные платформы
#
# Сохраните игры в формате json, оставив только игры, выпущенные после 2000 года
#
# Чтобы было проще, в репозитории с ДЗ выложены скрины, где можно посмотреть, где и какие поля находятся

# %%
import json

from scrapy import Item, signals, Spider, Field, Request
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings
from scrapy.signalmanager import dispatcher
from datetime import datetime

# %%
# список из запросов для поиска
queries = ['инди', 'стратегия', 'fps']

# %%
class Product(Item):
    url = Field()
    title = Field()
    category = Field()
    reviews_count = Field()
    rating = Field()
    release_date = Field()
    developer = Field()
    tags = Field()
    price = Field()
    platforms = Field()

    def to_dict(self):
        return {
            'url': self.get('url'),
            'title': self.get('title'),
            'category': self.get('category'),
            'reviews_count': self.get('reviews_count'),
            'rating': self.get('rating'),
            'release_date': self.get('release_date'),
            'developer': self.get('developer'),
            'tags': self.get('tags'),
            'price': self.get('price'),
            'platforms': self.get('platforms')
        }

    def get_release_year(self):
        try:
            return datetime.strptime(self.get('release_date'), '%d %b, %Y').year
        except ValueError:
            # иногда дата выхода игры - это некоторая строка, в которой нет года (например, Coming Soon)
            # в таком случае считаем, что игра нам подходит и вышла в текущем году
            return datetime.now().year

# %%
def digitify(string):
    """ Получаем строку и удаляем все, кроме цифр """
    return ''.join([ch for ch in string if ch.isdigit()])

# %%
class SteamSpider(Spider):
    name = 'steamparser'
    allowed_domains = ['store.steampowered.com']
    max_page = 2 # по заданию не нужно заходить дальше 2 страницы каталога

    def __init__(self, query, **kwargs):
        self.query = query
        self.start_urls = [f'https://store.steampowered.com/search/?term={self.query}']
        super().__init__(**kwargs)

    def start_requests(self):
        for page_num in range(1, self.max_page + 1):
            url = f'https://store.steampowered.com/search/?term={self.query}&page={page_num}'
            yield Request(url, callback=self.parse_catalog)

    def parse_catalog(self, response):
        for game_href in response.css('.search_result_row::attr("href")').extract():
            if not '/bundle/' in game_href:
                # если ссылка имеет вид *.com/bundle/* значит - это набор, а не игра
                yield Request(response.urljoin(game_href), callback=self.parse_game)

    def parse_game(self, response):
        
        title = response.css('#appHubAppName::text').extract_first('').strip()
        category = response.css('.blockbg').css('a::text').extract()[1:]
        reviews_count = response.css('.game_review_summary').xpath('..')
        reviews_count = reviews_count.css('.responsive_hidden::text').extract_first('')
        reviews_count = digitify(reviews_count)
        rating = response.css('.game_review_summary::text').extract_first('').strip()
        release_date = response.css('.date::text').extract_first('')
        developer = response.css('#developers_list').css('a::text').extract_first('').strip()
        tags = ','.join([tag.strip() for tag in response.css('.app_tag::text').extract()])
        price = response.css('[data-price-final]::attr("data-price-final")').extract_first('')
        try:
            price = float(price[:-2] + '.' + price[-2:])
        except ValueError:
            price = 'Бесплатно'
        platforms = response.css('[data-os]::attr("data-os")').extract()
        platforms = list(set(platforms))

        yield Product(
            url=response.request.url,
            title=title,
            category=category,
            reviews_count=reviews_count,
            rating=rating,
            release_date=release_date,
            developer=developer,
            tags=tags,
            price=price,
            platforms=platforms
        )

# %%
games = []

def crawler_results(signal, sender, item, response, spider):
    games.append(item)

dispatcher.connect(crawler_results, signal=signals.item_passed)

process = CrawlerProcess(get_project_settings())
process.settings.set('LOG_LEVEL', 'ERROR')
for query in queries:
    process.crawl(SteamSpider, query=query)
process.start()
# Out:
# INFO:scrapy.utils.log:Scrapy 2.7.1 started (bot: scrapybot)
# 2022-12-07 18:19:38 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: scrapybot)
# INFO:scrapy.utils.log:Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.0, Twisted 22.10.0, Python 3.8.15 (default, Oct 12 2022, 19:14:39) - [GCC 7.5.0], pyOpenSSL 22.1.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 38.0.4, Platform Linux-5.10.133+-x86_64-with-glibc2.27
# 2022-12-07 18:19:38 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.0, Twisted 22.10.0, Python 3.8.15 (default, Oct 12 2022, 19:14:39) - [GCC 7.5.0], pyOpenSSL 22.1.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 38.0.4, Platform Linux-5.10.133+-x86_64-with-glibc2.27
# INFO:scrapy.crawler:Overridden settings:
# {'LOG_LEVEL': 'ERROR'}
# 2022-12-07 18:19:38 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 'ERROR'}
# /usr/local/lib/python3.8/dist-packages/scrapy/utils/request.py:231: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
# DEBUG:scrapy.utils.log:Using reactor: twisted.internet.epollreactor.EPollReactor
# INFO:scrapy.extensions.telnet:Telnet Password: d37df02b8c6b5a6c
# INFO:scrapy.middleware:Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# INFO:scrapy.middleware:Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# INFO:scrapy.middleware:Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# INFO:scrapy.middleware:Enabled item pipelines:
# []
# INFO:scrapy.core.engine:Spider opened
# INFO:scrapy.extensions.logstats:Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# INFO:scrapy.extensions.telnet:Telnet console listening on 127.0.0.1:6023
# INFO:scrapy.crawler:Overridden settings:
# {'LOG_LEVEL': 'ERROR'}
# /usr/local/lib/python3.8/dist-packages/scrapy/utils/request.py:231: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
# INFO:scrapy.extensions.telnet:Telnet Password: 458db6e32a3ea4e2
# INFO:scrapy.middleware:Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# INFO:scrapy.middleware:Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# INFO:scrapy.middleware:Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# INFO:scrapy.middleware:Enabled item pipelines:
# []
# INFO:scrapy.core.engine:Spider opened
# INFO:scrapy.extensions.logstats:Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# INFO:scrapy.extensions.telnet:Telnet console listening on 127.0.0.1:6024
# INFO:scrapy.crawler:Overridden settings:
# {'LOG_LEVEL': 'ERROR'}
# INFO:scrapy.extensions.telnet:Telnet Password: de63619425bf1543
# INFO:scrapy.middleware:Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# INFO:scrapy.middleware:Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# INFO:scrapy.middleware:Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# INFO:scrapy.middleware:Enabled item pipelines:
# []
# INFO:scrapy.core.engine:Spider opened
# INFO:scrapy.extensions.logstats:Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# INFO:scrapy.extensions.telnet:Telnet console listening on 127.0.0.1:6025
# DEBUG:filelock:Attempting to acquire lock 140423300489856 on /root/.cache/python-tldextract/3.8.15.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# DEBUG:filelock:Lock 140423300489856 acquired on /root/.cache/python-tldextract/3.8.15.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# DEBUG:filelock:Attempting to acquire lock 140423300491680 on /root/.cache/python-tldextract/3.8.15.final__usr__7d8fdf__tldextract-3.4.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# DEBUG:filelock:Lock 140423300491680 acquired on /root/.cache/python-tldextract/3.8.15.final__usr__7d8fdf__tldextract-3.4.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): publicsuffix.org:443
# DEBUG:urllib3.connectionpool:https://publicsuffix.org:443 "GET /list/public_suffix_list.dat HTTP/1.1" 200 None
# DEBUG:filelock:Attempting to release lock 140423300491680 on /root/.cache/python-tldextract/3.8.15.final__usr__7d8fdf__tldextract-3.4.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# DEBUG:filelock:Lock 140423300491680 released on /root/.cache/python-tldextract/3.8.15.final__usr__7d8fdf__tldextract-3.4.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# DEBUG:filelock:Attempting to release lock 140423300489856 on /root/.cache/python-tldextract/3.8.15.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# DEBUG:filelock:Lock 140423300489856 released on /root/.cache/python-tldextract/3.8.15.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/search/?term=fps&page=1> (referer: None)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=2> (referer: None)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1> (referer: None)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2> (referer: None)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/search/?term=fps&page=2> (referer: None)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=1> (referer: None)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/2021910/FPS_Chess/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1935630/HoopsFPS/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/2021910/FPS_Chess/?snr=1_7_7_151_150_1>
# {'category': ['Free to Play Games'],
#  'developer': 'Meta Fork',
#  'platforms': ['win'],
#  'price': 'Бесплатно',
#  'rating': 'Very Positive',
#  'release_date': 'Jul 16, 2022',
#  'reviews_count': '3589',
#  'tags': 'FPS,PvP,Board Game,Shooter,Sports,Strategy,Tabletop,Turn-Based '
#          'Strategy,3D,Action,First-Person,Funny,Casual,Multiplayer,Stylized,Family '
#          'Friendly,Free to Play,Psychological Horror,Chess,Local Multiplayer,+',
#  'title': 'FPS Chess',
#  'url': 'https://store.steampowered.com/app/2021910/FPS_Chess/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1935630/HoopsFPS/?snr=1_7_7_151_150_1>
# {'category': ['Sports Games'],
#  'developer': 'Ronald Elizondo',
#  'platforms': ['win'],
#  'price': 2.0,
#  'rating': '',
#  'release_date': 'Apr 8, 2022',
#  'reviews_count': '',
#  'tags': 'Sports,eSports,Shooter,FPS,3D,Colorful,First-Person,Casual,Simulation,Basketball,Multiplayer,PvP,Action,Massively '
#          'Multiplayer,+',
#  'title': 'HoopsFPS',
#  'url': 'https://store.steampowered.com/app/1935630/HoopsFPS/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.downloadermiddlewares.redirect:Redirecting (302) to <GET https://store.steampowered.com/agecheck/app/252490/?snr=1_7_7_151_150_1> from <GET https://store.steampowered.com/app/252490/Rust/?snr=1_7_7_151_150_1>
# DEBUG:scrapy.downloadermiddlewares.redirect:Redirecting (302) to <GET https://store.steampowered.com/agecheck/app/1151340/?snr=1_7_7_151_150_1> from <GET https://store.steampowered.com/app/1151340/Fallout_76/?snr=1_7_7_151_150_1>
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/268200/Antisquad/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/453510/One_Man_Is_Not_No_Man/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/436260/Ultimate_Arena_FPS/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/2006390/Valand/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1103250/FORT/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/2104960/Dash_FPS/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/683830/Weable/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1162880/Pax_Ruthenia/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/268200/Antisquad/?snr=1_7_7_151_150_2>
# {'category': ['Strategy Games'],
#  'developer': 'InsGames',
#  'platforms': ['linux', 'win', 'mac'],
#  'price': 5.99,
#  'rating': 'Mixed',
#  'release_date': 'Oct 31, 2014',
#  'reviews_count': '127',
#  'tags': 'Strategy,Turn-Based,Turn-Based '
#          'Strategy,Action,Adventure,Tactical,Singleplayer,Indie,Turn-Based '
#          'Tactics,Early Access,+',
#  'title': 'Antisquad',
#  'url': 'https://store.steampowered.com/app/268200/Antisquad/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/453510/One_Man_Is_Not_No_Man/?snr=1_7_7_151_150_2>
# {'category': ['Action Games'],
#  'developer': 'TEN TIULENYA team',
#  'platforms': ['win'],
#  'price': 'Бесплатно',
#  'rating': 'Very Positive',
#  'release_date': 'Mar 18, 2016',
#  'reviews_count': '63',
#  'tags': 'Indie,Action,Medieval,Difficult,Free to Play,+',
#  'title': 'One Man Is Not No Man',
#  'url': 'https://store.steampowered.com/app/453510/One_Man_Is_Not_No_Man/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/488280/Gun_Done/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/436260/Ultimate_Arena_FPS/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': 'Kenneth Caselli',
#  'platforms': ['win'],
#  'price': 17.99,
#  'rating': 'Mixed',
#  'release_date': 'Sep 5, 2016',
#  'reviews_count': '203',
#  'tags': 'Action,Indie,FPS,Arena Shooter,Multiplayer,Memes,Early '
#          'Access,Competitive,Dating Sim,Psychological Horror,Family '
#          'Friendly,Heist,Anime,+',
#  'title': 'Ultimate Arena FPS',
#  'url': 'https://store.steampowered.com/app/436260/Ultimate_Arena_FPS/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/2006390/Valand/?snr=1_7_7_151_150_1>
# {'category': ['Strategy Games'],
#  'developer': 'LOMS Studio',
#  'platforms': ['win'],
#  'price': 7.99,
#  'rating': 'Very Positive',
#  'release_date': 'Nov 4, 2022',
#  'reviews_count': '16',
#  'tags': 'Simulation,Action,City Builder,Life Sim,RTS,Real Time '
#          'Tactics,Third-Person Shooter,Top-Down Shooter,3D,Third '
#          'Person,Military,War,Historical,Nature,Swordplay,Medieval,Archery,Tactical,Economy,Management,+',
#  'title': 'Valand',
#  'url': 'https://store.steampowered.com/app/2006390/Valand/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1714780/Cooking_Trip_New_Challenge_Original_Soundtrack/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.downloadermiddlewares.redirect:Redirecting (302) to <GET https://store.steampowered.com/agecheck/app/359550/?snr=1_7_7_151_150_1> from <GET https://store.steampowered.com/app/359550/Tom_Clancys_Rainbow_Six_Siege/?snr=1_7_7_151_150_1>
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/518790/theHunter_Call_of_the_Wild/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/833940/Vertigo_FPS/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1103250/FORT/?snr=1_7_7_151_150_2>
# {'category': ['Indie Games'],
#  'developer': 'PanzerCat',
#  'platforms': ['win'],
#  'price': 0.5,
#  'rating': '3 user reviews',
#  'release_date': 'Jul 15, 2019',
#  'reviews_count': '',
#  'tags': 'Indie,Simulation,Adventure,+',
#  'title': 'FORT',
#  'url': 'https://store.steampowered.com/app/1103250/FORT/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/696410/Toy_Generals/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/578080/PUBG_BATTLEGROUNDS/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/556780/Neptune_Arena_FPS/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1082990/DAMAGE/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/2104960/Dash_FPS/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': 'Vinny',
#  'platforms': ['win'],
#  'price': 2.99,
#  'rating': '2 user reviews',
#  'release_date': 'Aug 18, 2022',
#  'reviews_count': '',
#  'tags': 'FPS,Action,Multiplayer,Hero '
#          "Shooter,PvP,Shooter,Sniper,Realistic,Co-op,Shoot 'Em "
#          'Up,Gore,Violent,Online Co-Op,Singleplayer,First-Person,+',
#  'title': 'Dash FPS',
#  'url': 'https://store.steampowered.com/app/2104960/Dash_FPS/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/683830/Weable/?snr=1_7_7_151_150_1>
# {'category': ['Action Games', 'Valkyrie Initiative Franchise'],
#  'developer': 'SPECTRUM GAMES',
#  'platforms': ['win'],
#  'price': 0.99,
#  'rating': 'Mostly Positive',
#  'release_date': 'Aug 23, 2017',
#  'reviews_count': '183',
#  'tags': 'Action,Indie,Casual,2D,Top-Down,+',
#  'title': 'Weable',
#  'url': 'https://store.steampowered.com/app/683830/Weable/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1162880/Pax_Ruthenia/?snr=1_7_7_151_150_2>
# {'category': ['Strategy Games'],
#  'developer': 'Venezem',
#  'platforms': ['win'],
#  'price': 4.99,
#  'rating': '8 user reviews',
#  'release_date': 'Nov 28, 2019',
#  'reviews_count': '',
#  'tags': 'Strategy,Indie,Simulation,Politics,Singleplayer,Choose Your Own '
#          'Adventure,Multiple Endings,Difficult,+',
#  'title': 'Pax Ruthenia',
#  'url': 'https://store.steampowered.com/app/1162880/Pax_Ruthenia/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1576790/FPS_Tactics/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/290730/My_Lands_Black_Gem_Hunting/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/313310/My_Lands_Hero_Courage__Starter_DLC_Pack/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/440/Team_Fortress_2/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/411760/Swordbreaker_The_Game/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/488280/Gun_Done/?snr=1_7_7_151_150_1>
# {'category': ['Casual Games'],
#  'developer': 'AZAMATIKA',
#  'platforms': ['win'],
#  'price': 0.99,
#  'rating': 'Very Positive',
#  'release_date': 'Jun 13, 2016',
#  'reviews_count': '535',
#  'tags': 'Casual,Indie,Western,Pixel Graphics,Memes,Arcade,+',
#  'title': 'Gun Done',
#  'url': 'https://store.steampowered.com/app/488280/Gun_Done/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1525890/Death_Park_2/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1562870/Mind_Rite/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/818700/Warbanners_Death_Speaker/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.downloadermiddlewares.redirect:Redirecting (302) to <GET https://store.steampowered.com/agecheck/app/1938090/?snr=1_7_7_151_150_1> from <GET https://store.steampowered.com/app/1938090/Call_of_Duty_Modern_Warfare_II/?snr=1_7_7_151_150_1>
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/643650/Ken_Folletts_The_Pillars_of_the_Earth__Soundtrack/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/874700/The_Putinland_Divide__Conquer/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1714780/Cooking_Trip_New_Challenge_Original_Soundtrack/?snr=1_7_7_151_150_2>
# {'category': ['Casual Games',
#               'Cooking Trip New Challenge',
#               'Downloadable Content'],
#  'developer': 'GameOn Production',
#  'platforms': ['win'],
#  'price': 2.99,
#  'rating': '',
#  'release_date': 'Aug 10, 2021',
#  'reviews_count': '',
#  'tags': 'Casual,+',
#  'title': 'Cooking Trip New Challenge Original Soundtrack',
#  'url': 'https://store.steampowered.com/app/1714780/Cooking_Trip_New_Challenge_Original_Soundtrack/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/518790/theHunter_Call_of_the_Wild/?snr=1_7_7_151_150_1>
# {'category': ['Adventure Games'],
#  'developer': 'Expansive Worlds',
#  'platforms': ['win'],
#  'price': 19.99,
#  'rating': 'Very Positive',
#  'release_date': 'Feb 16, 2017',
#  'reviews_count': '2324',
#  'tags': 'Hunting,Open '
#          'World,Multiplayer,Simulation,First-Person,Shooter,Survival,Realistic,Co-op,Adventure,FPS,Action,Singleplayer,Walking '
#          'Simulator,Online Co-Op,Atmospheric,Sports,Combat,Strategy,Gore,+',
#  'title': 'theHunter: Call of the Wild™',
#  'url': 'https://store.steampowered.com/app/518790/theHunter_Call_of_the_Wild/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/833940/Vertigo_FPS/?snr=1_7_7_151_150_1>
# {'category': ['Violent Games'],
#  'developer': 'Lothor',
#  'platforms': ['win'],
#  'price': 4.99,
#  'rating': '1 user reviews',
#  'release_date': 'Jun 27, 2018',
#  'reviews_count': '',
#  'tags': 'Action,Indie,Early Access,Casual,Violent,+',
#  'title': 'Vertigo FPS',
#  'url': 'https://store.steampowered.com/app/833940/Vertigo_FPS/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/696410/Toy_Generals/?snr=1_7_7_151_150_2>
# {'category': ['Strategy Games'],
#  'developer': 'Arjuna Games',
#  'platforms': ['win'],
#  'price': 9.99,
#  'rating': '9 user reviews',
#  'release_date': 'Apr 19, 2018',
#  'reviews_count': '',
#  'tags': 'Strategy,Indie,Early Access,Real Time '
#          'Tactics,Military,RTS,War,Tactical,+',
#  'title': 'Toy Generals',
#  'url': 'https://store.steampowered.com/app/696410/Toy_Generals/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/578080/PUBG_BATTLEGROUNDS/?snr=1_7_7_151_150_1>
# {'category': ['Free to Play Games'],
#  'developer': 'KRAFTON, Inc.',
#  'platforms': ['win'],
#  'price': 'Бесплатно',
#  'rating': 'Mostly Positive',
#  'release_date': 'Dec 21, 2017',
#  'reviews_count': '20829',
#  'tags': 'Survival,Shooter,Multiplayer,Battle Royale,FPS,PvP,Third-Person '
#          'Shooter,Action,Online '
#          'Co-Op,Tactical,Co-op,First-Person,Strategy,Early '
#          'Access,Competitive,Third '
#          'Person,Team-Based,Difficult,Simulation,Stealth,+',
#  'title': 'PUBG: BATTLEGROUNDS',
#  'url': 'https://store.steampowered.com/app/578080/PUBG_BATTLEGROUNDS/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/556780/Neptune_Arena_FPS/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': 'GENOVA Softworks',
#  'platforms': ['win'],
#  'price': 2.99,
#  'rating': 'Mixed',
#  'release_date': 'Dec 19, 2016',
#  'reviews_count': '45',
#  'tags': 'Action,Indie,Casual,FPS,Arena Shooter,+',
#  'title': 'Neptune: Arena FPS',
#  'url': 'https://store.steampowered.com/app/556780/Neptune_Arena_FPS/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1082990/DAMAGE/?snr=1_7_7_151_150_2>
# {'category': ['Indie Games'],
#  'developer': 'Damage Team',
#  'platforms': ['win'],
#  'price': 0.37,
#  'rating': '2 user reviews',
#  'release_date': 'Jul 18, 2019',
#  'reviews_count': '',
#  'tags': 'Indie,Casual,Action,Tanks,Old School,Retro,Difficult,Top-Down '
#          'Shooter,Adventure,Shooter,+',
#  'title': 'D.A.M.A.G.E',
#  'url': 'https://store.steampowered.com/app/1082990/DAMAGE/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/agecheck/app/1151340/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.downloadermiddlewares.redirect:Redirecting (302) to <GET https://store.steampowered.com/agecheck/app/377160/?snr=1_7_7_151_150_2> from <GET https://store.steampowered.com/app/377160/Fallout_4/?snr=1_7_7_151_150_2>
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/agecheck/app/252490/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/575780/Inner_silence/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1361210/Warhammer_40000_Darktide/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/749250/7th_Sector/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1452870/Roads_of_Time_2_Odyssey/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1029470/Angry_Farm/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1960590/I_Am_Sakuya_Touhou_FPS_Game/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=fps&page=2)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1576790/FPS_Tactics/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': 'Hede',
#  'platforms': ['linux', 'win', 'mac'],
#  'price': 9.99,
#  'rating': '4 user reviews',
#  'release_date': 'Apr 5, 2021',
#  'reviews_count': '',
#  'tags': 'Exploration,Tactical RPG,3D Platformer,Action RTS,Immersive '
#          "Sim,Shoot 'Em Up,Hack and Slash,FPS,Tower "
#          'Defense,Platformer,RTS,Strategy RPG,Strategy,Action '
#          'RPG,3D,First-Person,Military,Stealth,Investigation,Physics,+',
#  'title': 'FPS Tactics',
#  'url': 'https://store.steampowered.com/app/1576790/FPS_Tactics/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/290730/My_Lands_Black_Gem_Hunting/?snr=1_7_7_151_150_1>
# {'category': ['Free to Play Games'],
#  'developer': 'Gravvit Ltd',
#  'platforms': ['win'],
#  'price': 'Бесплатно',
#  'rating': 'Very Positive',
#  'release_date': 'Sep 16, 2014',
#  'reviews_count': '3281',
#  'tags': 'Strategy,Free to Play,RTS,Massively '
#          'Multiplayer,Multiplayer,Indie,Casual,Adventure,MMORPG,Singleplayer,Co-op,RPG,2D,+',
#  'title': 'My Lands: Black Gem Hunting',
#  'url': 'https://store.steampowered.com/app/290730/My_Lands_Black_Gem_Hunting/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/313310/My_Lands_Hero_Courage__Starter_DLC_Pack/?snr=1_7_7_151_150_2>
# {'category': ['Free to Play Games',
#               'My Lands: Black Gem Hunting',
#               'Downloadable Content'],
#  'developer': 'Gravvit Ltd',
#  'platforms': ['win'],
#  'price': 17.99,
#  'rating': '1 user reviews',
#  'release_date': 'Sep 16, 2014',
#  'reviews_count': '',
#  'tags': 'Massively Multiplayer,Indie,Strategy,Free to Play,Casual,+',
#  'title': 'My Lands: Hero Courage - Starter DLC Pack',
#  'url': 'https://store.steampowered.com/app/313310/My_Lands_Hero_Courage__Starter_DLC_Pack/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/440/Team_Fortress_2/?snr=1_7_7_151_150_1>
# {'category': ['Free to Play Games'],
#  'developer': 'Valve',
#  'platforms': ['linux', 'win', 'mac'],
#  'price': 19.99,
#  'rating': 'Overwhelmingly Positive',
#  'release_date': 'Oct 10, 2007',
#  'reviews_count': '17244',
#  'tags': 'Free to Play,Hero '
#          'Shooter,Multiplayer,FPS,Shooter,Action,Class-Based,Team-Based,Funny,First-Person,Online '
#          'Co-Op,Competitive,Cartoony,Trading,Co-op,Comedy,Robots,Tactical,Cartoon,Crafting,+',
#  'title': 'Team Fortress 2',
#  'url': 'https://store.steampowered.com/app/440/Team_Fortress_2/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/411760/Swordbreaker_The_Game/?snr=1_7_7_151_150_1>
# {'category': ['Indie Games', 'DuCats Games Franchise'],
#  'developer': 'DuCats Games Studio',
#  'platforms': ['win', 'mac'],
#  'price': 2.99,
#  'rating': 'Very Positive',
#  'release_date': 'Nov 6, 2015',
#  'reviews_count': '266',
#  'tags': 'Adventure,Indie,Interactive Fiction,Visual Novel,Choices Matter,Dark '
#          'Fantasy,Exploration,Medieval,2D,Gore,Fantasy,Point & '
#          'Click,Comedy,Dungeon Crawler,Replay '
#          'Value,Atmospheric,Aliens,Magic,Funny,Singleplayer,+',
#  'title': 'Swordbreaker The Game',
#  'url': 'https://store.steampowered.com/app/411760/Swordbreaker_The_Game/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1804170/Mimicry/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.downloadermiddlewares.redirect:Redirecting (302) to <GET https://store.steampowered.com/agecheck/app/924970/?snr=1_7_7_151_150_2> from <GET https://store.steampowered.com/app/924970/Back_4_Blood/?snr=1_7_7_151_150_2>
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/628440/Multiplayer_FPS_Demo/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/2077060/SATUS/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/712230/WARZONE/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1474940/Royal_Roads_2_The_Magic_Box/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1566820/Cooking_Trip_New_Challenge/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/2082000/WORMWOOD/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/930640/Code_Brown/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/874020/Lost_Artifacts_Soulstone/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1525890/Death_Park_2/?snr=1_7_7_151_150_1>
# {'category': ['Adventure Games'],
#  'developer': 'Euphoria Games',
#  'platforms': ['win'],
#  'price': 5.99,
#  'rating': 'Very Positive',
#  'release_date': 'Feb 24, 2021',
#  'reviews_count': '107',
#  'tags': 'Adventure,Action,Puzzle,Arcade,Exploration,Hidden '
#          'Object,Horror,Survival Horror,FPS,First-Person,Dark,Psychological '
#          'Horror,Indie,Singleplayer,Blood,Gore,Violent,Replay '
#          'Value,Difficult,+',
#  'title': 'Death Park 2',
#  'url': 'https://store.steampowered.com/app/1525890/Death_Park_2/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1562870/Mind_Rite/?snr=1_7_7_151_150_1>
# {'category': ['Indie Games'],
#  'developer': 'Albino Studio',
#  'platforms': ['win'],
#  'price': 6.99,
#  'rating': 'Positive',
#  'release_date': 'Feb 19, 2022',
#  'reviews_count': '25',
#  'tags': 'Indie,Casual,Visual '
#          'Novel,Otome,Singleplayer,Cute,Fantasy,Romance,Female '
#          'Protagonist,Choices Matter,Anime,2D,Detective,First-Person,Side '
#          'Scroller,+',
#  'title': 'Mind Rite',
#  'url': 'https://store.steampowered.com/app/1562870/Mind_Rite/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/818700/Warbanners_Death_Speaker/?snr=1_7_7_151_150_1>
# {'category': ['Strategy Games', 'Warbanners', 'Downloadable Content'],
#  'developer': 'Crasleen Games',
#  'platforms': ['linux', 'win'],
#  'price': 4.99,
#  'rating': 'Positive',
#  'release_date': 'Mar 29, 2018',
#  'reviews_count': '15',
#  'tags': 'Strategy,RPG,Indie,Turn-Based Combat,Singleplayer,Tactical RPG,Dark '
#          'Fantasy,Medieval,Turn-Based '
#          'Tactics,Adventure,Fantasy,Tactical,Turn-Based Strategy,Story '
#          'Rich,2D,Difficult,Atmospheric,Strategy RPG,Turn-Based,+',
#  'title': 'Warbanners: Death Speaker',
#  'url': 'https://store.steampowered.com/app/818700/Warbanners_Death_Speaker/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/643650/Ken_Folletts_The_Pillars_of_the_Earth__Soundtrack/?snr=1_7_7_151_150_1>
# {'category': ['Indie Games',
#               'Daedalic Entertainment Franchise',
#               "Ken Follett's The Pillars of the Earth",
#               'Downloadable Content'],
#  'developer': 'Daedalic Entertainment',
#  'platforms': ['win'],
#  'price': 2.99,
#  'rating': 'Positive',
#  'release_date': 'Aug 15, 2017',
#  'reviews_count': '24',
#  'tags': 'Adventure,Indie,Casual,Violent,+',
#  'title': "Ken Follett's The Pillars of the Earth - Soundtrack",
#  'url': 'https://store.steampowered.com/app/643650/Ken_Folletts_The_Pillars_of_the_Earth__Soundtrack/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/874700/The_Putinland_Divide__Conquer/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': 'Tero Lunkka',
#  'platforms': ['win'],
#  'price': 0.49,
#  'rating': 'Positive',
#  'release_date': 'Jul 3, 2018',
#  'reviews_count': '10',
#  'tags': 'Action,Indie,Gore,Violent,FPS,+',
#  'title': 'The Putinland: Divide & Conquer',
#  'url': 'https://store.steampowered.com/app/874700/The_Putinland_Divide__Conquer/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/agecheck/app/359550/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=fps&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1797450/FPS_Arena_Online/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=fps&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1225810/FOS/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1294920/Another_FPS_Game/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=fps&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1449430/Jendo_Origins/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1186030/Death_Park/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1761040/Gear_of_Glass_Eolarns_war/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/790930/Primitive_Shooter/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/384300/CPUCores__Maximize_Your_FPS/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=fps&page=2)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/agecheck/app/1151340/?snr=1_7_7_151_150_1>
# {'category': [],
#  'developer': '',
#  'platforms': [],
#  'price': 'Бесплатно',
#  'rating': '',
#  'release_date': '',
#  'reviews_count': '',
#  'tags': '',
#  'title': '',
#  'url': 'https://store.steampowered.com/agecheck/app/1151340/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/agecheck/app/252490/?snr=1_7_7_151_150_1>
# {'category': [],
#  'developer': '',
#  'platforms': [],
#  'price': 'Бесплатно',
#  'rating': '',
#  'release_date': '',
#  'reviews_count': '',
#  'tags': '',
#  'title': '',
#  'url': 'https://store.steampowered.com/agecheck/app/252490/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/575780/Inner_silence/?snr=1_7_7_151_150_1>
# {'category': ['Action Games', 'Volens Nolens Games Franchise'],
#  'developer': 'Volens Nolens Games',
#  'platforms': ['win'],
#  'price': 0.3,
#  'rating': 'Positive',
#  'release_date': 'Feb 11, 2017',
#  'reviews_count': '43',
#  'tags': 'Action,Adventure,Casual,Indie,Platformer,Pixel '
#          'Graphics,2D,Puzzle,Puzzle Platformer,Retro,Bullet '
#          'Time,Singleplayer,+',
#  'title': 'Inner silence',
#  'url': 'https://store.steampowered.com/app/575780/Inner_silence/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1361210/Warhammer_40000_Darktide/?snr=1_7_7_151_150_1>
# {'category': ['Action Games', 'Warhammer Franchise'],
#  'developer': 'Fatshark',
#  'platforms': ['win'],
#  'price': 39.99,
#  'rating': 'Mixed',
#  'release_date': 'Nov 30, 2022',
#  'reviews_count': '34655',
#  'tags': 'Warhammer 40K,Multiplayer,Online '
#          'Co-Op,Adventure,PvE,Gore,FPS,Singleplayer,Shooter,Hack and '
#          'Slash,Action,Co-op,First-Person,Character '
#          'Customization,Violent,Atmospheric,Looter '
#          'Shooter,Action-Adventure,Survival Horror,Sci-fi,+',
#  'title': 'Warhammer 40,000: Darktide',
#  'url': 'https://store.steampowered.com/app/1361210/Warhammer_40000_Darktide/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/749250/7th_Sector/?snr=1_7_7_151_150_1>
# {'category': ['Indie Games'],
#  'developer': 'Носков Сергей',
#  'platforms': ['win'],
#  'price': 12.99,
#  'rating': 'Mostly Positive',
#  'release_date': 'Mar 5, 2019',
#  'reviews_count': '510',
#  'tags': '3D Platformer,Puzzle Platformer,Racing,PvE,Walking '
#          'Simulator,Arcade,Third Person,Noir,Cyberpunk,Alternate '
#          'History,Horror,Choices Matter,Multiple '
#          'Endings,Action,Stylized,Sci-fi,Philosophical,Adventure,Beautiful,Singleplayer,+',
#  'title': '7th Sector',
#  'url': 'https://store.steampowered.com/app/749250/7th_Sector/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1452870/Roads_of_Time_2_Odyssey/?snr=1_7_7_151_150_2>
# {'category': ['Casual Games'],
#  'developer': 'GameOn Production',
#  'platforms': ['win'],
#  'price': 4.99,
#  'rating': '7 user reviews',
#  'release_date': 'Apr 8, 2021',
#  'reviews_count': '',
#  'tags': 'Casual,Strategy,Adventure,Indie,Singleplayer,Time Management,+',
#  'title': 'Roads of Time 2: Odyssey',
#  'url': 'https://store.steampowered.com/app/1452870/Roads_of_Time_2_Odyssey/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1029470/Angry_Farm/?snr=1_7_7_151_150_2>
# {'category': ['Strategy Games'],
#  'developer': 'SAFING',
#  'platforms': ['win'],
#  'price': 0.39,
#  'rating': '3 user reviews',
#  'release_date': 'Jul 18, 2019',
#  'reviews_count': '',
#  'tags': 'Indie,Strategy,Action,Arcade,Action-Adventure,+',
#  'title': 'Angry Farm',
#  'url': 'https://store.steampowered.com/app/1029470/Angry_Farm/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1960590/I_Am_Sakuya_Touhou_FPS_Game/?snr=1_7_7_151_150_2>
# {'category': ['Action Games'],
#  'developer': 'Sigyaad Team',
#  'platforms': ['win'],
#  'price': 7.99,
#  'rating': 'Very Positive',
#  'release_date': 'Sep 13, 2022',
#  'reviews_count': '46',
#  'tags': 'FPS,Action,First-Person,Bullet Hell,Shooter,Female '
#          'Protagonist,Retro,Anime,2D,Pixel '
#          'Graphics,Difficult,Colorful,Cute,Atmospheric,Singleplayer,Faith,+',
#  'title': 'I Am Sakuya: Touhou FPS Game',
#  'url': 'https://store.steampowered.com/app/1960590/I_Am_Sakuya_Touhou_FPS_Game/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1804170/Mimicry/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': 'Euphoria Games',
#  'platforms': ['win'],
#  'price': 4.99,
#  'rating': 'Very Positive',
#  'release_date': 'Aug 25, 2022',
#  'reviews_count': '13',
#  'tags': 'Survival,Action,Space,Minigames,Horror,Gore,Blood,Online '
#          'Co-Op,Multiplayer,Psychological '
#          'Horror,Violent,Co-op,Team-Based,Stealth,Indie,Atmospheric,Survival '
#          'Horror,Social Deduction,Casual,3D,+',
#  'title': 'Mimicry',
#  'url': 'https://store.steampowered.com/app/1804170/Mimicry/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/628440/Multiplayer_FPS_Demo/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': 'Vitor Pêgas',
#  'platforms': ['win'],
#  'price': 'Бесплатно',
#  'rating': 'Mixed',
#  'release_date': 'Jul 6, 2017',
#  'reviews_count': '200',
#  'tags': 'Free to Play,Action,Casual,Indie,Multiplayer,FPS,Zombies,+',
#  'title': 'Multiplayer FPS Demo',
#  'url': 'https://store.steampowered.com/app/628440/Multiplayer_FPS_Demo/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/693800/Loco_Parentis/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.downloadermiddlewares.redirect:Redirecting (302) to <GET https://store.steampowered.com/agecheck/app/594650/?snr=1_7_7_151_150_2> from <GET https://store.steampowered.com/app/594650/Hunt_Showdown/?snr=1_7_7_151_150_2>
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/639840/FIELD_BREAKING/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/46380/Reign_Conflict_of_Nations/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/578690/Dog_Duty/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/713010/WARIUM/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/473550/SnowBall_FPS/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=fps&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1285000/Stayhome_Simulator/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D0%B8%D0%BD%D0%B4%D0%B8&page=1)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/1647990/Ningakki_XXVI_FPS/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=fps&page=2)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/696400/NeoBoom/?snr=1_7_7_151_150_1> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=1)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/2077060/SATUS/?snr=1_7_7_151_150_2>
# {'category': ['Strategy Games'],
#  'developer': 'Strudio Company',
#  'platforms': ['win'],
#  'price': 'Бесплатно',
#  'rating': '',
#  'release_date': 'Feb 10, 2023',
#  'reviews_count': '',
#  'tags': 'Action,War,Grand Strategy,Turn-Based Strategy,Strategy,Turn-Based '
#          'Tactics,2D,3D,Pixel '
#          'Graphics,Magic,Tactical,Fantasy,Singleplayer,Choices '
#          'Matter,Simulation,Casual,Indie,Adventure,+',
#  'title': 'SATUS',
#  'url': 'https://store.steampowered.com/app/2077060/SATUS/?snr=1_7_7_151_150_2'}
# ...
# {'category': ['Casual Games',
#               'Katy and Bob: Cake Café',
#               'Downloadable Content'],
#  'developer': 'Workroom7',
#  'platforms': ['win'],
#  'price': 4.99,
#  'rating': '',
#  'release_date': 'Jan 29, 2019',
#  'reviews_count': '',
#  'tags': 'Casual,Strategy,+',
#  'title': 'Katy & Bob: Cake Café Soundtrack',
#  'url': 'https://store.steampowered.com/app/983460/Katy__Bob_Cake_Caf_Soundtrack/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1899790/MALFUNCTION_FPS/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': 'HOIman',
#  'platforms': ['win'],
#  'price': 'Бесплатно',
#  'rating': 'Mostly Positive',
#  'release_date': 'Feb 23, 2022',
#  'reviews_count': '24',
#  'tags': 'FPS,Action,Shooter,3D '
#          'Fighter,3D,First-Person,Post-apocalyptic,Sci-fi,Robots,Free to '
#          'Play,Futuristic,Combat,Singleplayer,Hero Shooter,+',
#  'title': 'MALFUNCTION FPS',
#  'url': 'https://store.steampowered.com/app/1899790/MALFUNCTION_FPS/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/935790/Angry_Troll_Simulator/?snr=1_7_7_151_150_2>
# {'category': ['Indie Games'],
#  'developer': 'One Face Studio',
#  'platforms': ['win'],
#  'price': 0.99,
#  'rating': 'Positive',
#  'release_date': 'Oct 11, 2018',
#  'reviews_count': '14',
#  'tags': 'Adventure,Simulation,Indie,Memes,Life Sim,Idler,Exploration,Hidden '
#          'Object,3D,First-Person,Survival,Parody,Psychedelic,Relaxing,Funny,Fantasy,Comedy,Open '
#          'World,6DOF,Singleplayer,+',
#  'title': 'Angry Troll Simulator',
#  'url': 'https://store.steampowered.com/app/935790/Angry_Troll_Simulator/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://store.steampowered.com/app/386640/Affected_Zone_Tactics/?snr=1_7_7_151_150_2> (referer: https://store.steampowered.com/search/?term=%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F&page=2)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/908520/fpsVR/?snr=1_7_7_151_150_1>
# {'category': ['Utilities'],
#  'developer': 'SBSoftLab',
#  'platforms': ['win'],
#  'price': 3.99,
#  'rating': 'Very Positive',
#  'release_date': 'Sep 11, 2018',
#  'reviews_count': '29',
#  'tags': 'Utilities,Indie,VR,Software,Benchmark,Hardware,FPS,+',
#  'title': 'fpsVR',
#  'url': 'https://store.steampowered.com/app/908520/fpsVR/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/agecheck/app/1091500/?snr=1_7_7_151_150_2>
# {'category': [],
#  'developer': '',
#  'platforms': [],
#  'price': 'Бесплатно',
#  'rating': '',
#  'release_date': '',
#  'reviews_count': '',
#  'tags': '',
#  'title': '',
#  'url': 'https://store.steampowered.com/agecheck/app/1091500/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/444180/Techwars_Online/?snr=1_7_7_151_150_2>
# {'category': ['Strategy Games'],
#  'developer': 'Argus Games',
#  'platforms': ['win'],
#  'price': 4.99,
#  'rating': 'Mixed',
#  'release_date': 'Mar 17, 2016',
#  'reviews_count': '94',
#  'tags': 'Massively Multiplayer,Strategy,Indie,Action,Turn-Based '
#          'Strategy,Tactical,Multiplayer,Mechs,Singleplayer,Board '
#          'Game,Turn-Based,+',
#  'title': 'Techwars Online',
#  'url': 'https://store.steampowered.com/app/444180/Techwars_Online/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1945590/Linguist_FPS__The_Language_Learning_FPS/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': 'Rocket Boy Games',
#  'platforms': ['win'],
#  'price': 14.99,
#  'rating': 'Mostly Positive',
#  'release_date': 'May 20, 2022',
#  'reviews_count': '87',
#  'tags': "Action Roguelike,Education,FPS,Foreign,Perma Death,PvE,Shoot 'Em "
#          'Up,Difficult,Shooter,Cold War,Controller,Dynamic '
#          'Narration,Robots,Loot,Realistic,Narration,Action,3D,Procedural '
#          'Generation,Politics,+',
#  'title': 'Linguist FPS - The Language Learning FPS',
#  'url': 'https://store.steampowered.com/app/1945590/Linguist_FPS__The_Language_Learning_FPS/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1632040/Magic_defense/?snr=1_7_7_151_150_2>
# {'category': ['Strategy Games'],
#  'developer': 'Phoenixxx Games',
#  'platforms': ['win'],
#  'price': 6.99,
#  'rating': '2 user reviews',
#  'release_date': 'May 26, 2021',
#  'reviews_count': '',
#  'tags': 'Strategy,Tower Defense,Idler,Survival,Zombies,Resource '
#          'Management,Building,Base Building,2D,2D '
#          'Platformer,Cartoony,Hand-drawn,Colorful,Singleplayer,Logic,+',
#  'title': 'Magic defense',
#  'url': 'https://store.steampowered.com/app/1632040/Magic_defense/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1603600/Daldos/?snr=1_7_7_151_150_2>
# {'category': ['Strategy Games'],
#  'developer': 'Vanaheim Team',
#  'platforms': ['win'],
#  'price': 7.99,
#  'rating': '2 user reviews',
#  'release_date': 'Apr 18, 2022',
#  'reviews_count': '',
#  'tags': 'Historical,Medieval,Turn-Based Combat,Spectacle '
#          'fighter,Multiplayer,Turn-Based Strategy,Turn-Based Tactics,Tactical '
#          'RPG,Strategy,Tactical,PvE,Simulation,PvP,Top-Down,Combat,Realistic,Tabletop,Swordplay,Logic,Local '
#          'Multiplayer,+',
#  'title': 'Daldos',
#  'url': 'https://store.steampowered.com/app/1603600/Daldos/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1256380/FPS_Infinite/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': "Phr00t's Software",
#  'platforms': ['linux', 'win', 'mac'],
#  'price': 'Бесплатно',
#  'rating': 'Very Positive',
#  'release_date': 'Mar 16, 2020',
#  'reviews_count': '88',
#  'tags': 'Indie,Action,Adventure,FPS,Free to Play,VR,First-Person,Procedural '
#          'Generation,Metroidvania,3D Platformer,Sci-fi,Singleplayer,Bullet '
#          'Time,Time Attack,Stealth,Competitive,+',
#  'title': 'FPS Infinite',
#  'url': 'https://store.steampowered.com/app/1256380/FPS_Infinite/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/971460/FPS_Training/?snr=1_7_7_151_150_1>
# {'category': ['Action Games'],
#  'developer': 'Drago Software',
#  'platforms': ['win'],
#  'price': 4.99,
#  'rating': 'Mixed',
#  'release_date': 'Dec 14, 2018',
#  'reviews_count': '73',
#  'tags': 'Indie,Action,FPS,Shooter,First-Person,Education,Utilities,3D,Stylized,Cyberpunk,Futuristic,Military,Modern,Sci-fi,Sniper,Surreal,Combat,Gun '
#          'Customization,PvE,Singleplayer,+',
#  'title': 'FPS Training',
#  'url': 'https://store.steampowered.com/app/971460/FPS_Training/?snr=1_7_7_151_150_1'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1403190/Throne_of_Fate/?snr=1_7_7_151_150_2>
# {'category': ['Action Games'],
#  'developer': 'Enoops',
#  'platforms': ['win'],
#  'price': 10.99,
#  'rating': 'Positive',
#  'release_date': 'Oct 21, 2020',
#  'reviews_count': '17',
#  'tags': 'Adventure,RPG,Action,Platformer,Action-Adventure,Roguelike,Action '
#          'RPG,2D Platformer,Side Scroller,Mystery Dungeon,CRPG,Action '
#          'Roguelike,2D,Pixel '
#          'Graphics,Loot,Crafting,Underground,Magic,Character '
#          'Customization,Perma Death,+',
#  'title': 'Throne of Fate',
#  'url': 'https://store.steampowered.com/app/1403190/Throne_of_Fate/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/356130/Heroes_of_Scene/?snr=1_7_7_151_150_2>
# {'category': ['Strategy Games'],
#  'developer': 'Icy Donut',
#  'platforms': ['win'],
#  'price': 'Бесплатно',
#  'rating': 'Mixed',
#  'release_date': 'Aug 26, 2015',
#  'reviews_count': '673',
#  'tags': 'Free to Play,Strategy,Base Building,Multiplayer,Massively '
#          'Multiplayer,Indie,Building,Card Game,Trading Card Game,Tower '
#          'Defense,Tactical,RTS,Great Soundtrack,Action,+',
#  'title': 'Heroes of Scene',
#  'url': 'https://store.steampowered.com/app/356130/Heroes_of_Scene/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1016720/Save_Koch/?snr=1_7_7_151_150_2>
# {'category': ['Simulation Games'],
#  'developer': 'Wooden Monkeys',
#  'platforms': ['linux', 'win', 'mac'],
#  'price': 11.99,
#  'rating': 'Mixed',
#  'release_date': 'Apr 18, 2019',
#  'reviews_count': '111',
#  'tags': 'Strategy,Simulation,Adventure,Story '
#          'Rich,Atmospheric,Detective,Choices Matter,Singleplayer,Great '
#          'Soundtrack,2D,Replay '
#          'Value,Violent,Casual,Political,Indie,Difficult,Point & '
#          'Click,Multiple Endings,Management,Thriller,+',
#  'title': 'Save Koch',
#  'url': 'https://store.steampowered.com/app/1016720/Save_Koch/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1080700/Swordbreaker_Origins/?snr=1_7_7_151_150_2>
# {'category': ['Indie Games', 'DuCats Games Franchise'],
#  'developer': 'DuCats Games Studio',
#  'platforms': ['linux', 'win'],
#  'price': 9.99,
#  'rating': 'Positive',
#  'release_date': 'May 13, 2022',
#  'reviews_count': '19',
#  'tags': 'Indie,Gore,Violent,Adventure,Nudity,Visual Novel,Singleplayer,Replay '
#          'Value,2D,Exploration,Comedy,Interactive '
#          'Fiction,Hand-drawn,Stylized,Atmospheric,Parody,Medieval,Puzzle,Point '
#          '& Click,Difficult,+',
#  'title': 'Swordbreaker: Origins',
#  'url': 'https://store.steampowered.com/app/1080700/Swordbreaker_Origins/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1522140/Demon_Skin/?snr=1_7_7_151_150_2>
# {'category': ['Action Games', 'ESDigital Games Franchise'],
#  'developer': 'Ludus future',
#  'platforms': ['win'],
#  'price': 14.99,
#  'rating': 'Mostly Positive',
#  'release_date': 'Apr 13, 2021',
#  'reviews_count': '67',
#  'tags': 'Action,RPG,Hack and Slash,Side '
#          'Scroller,Dark,Singleplayer,Platformer,Dark Fantasy,Linear,3D,3D '
#          'Platformer,Adventure,Combat,3D '
#          "Fighter,Action-Adventure,2.5D,Atmospheric,Controller,Magic,Beat 'em "
#          'up,+',
#  'title': 'Demon Skin',
#  'url': 'https://store.steampowered.com/app/1522140/Demon_Skin/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/612510/The_Far_Frontier/?snr=1_7_7_151_150_2>
# {'category': ['Indie Games'],
#  'developer': 'Chillax Games Studio',
#  'platforms': ['win'],
#  'price': 2.99,
#  'rating': 'Mixed',
#  'release_date': 'Aug 15, 2017',
#  'reviews_count': '29',
#  'tags': 'Strategy,Indie,Casual,Match 3,+',
#  'title': 'The Far Frontier',
#  'url': 'https://store.steampowered.com/app/612510/The_Far_Frontier/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1650080/Mysterious_Blocks_2/?snr=1_7_7_151_150_2>
# {'category': ['Indie Games'],
#  'developer': 'Enoops',
#  'platforms': ['win'],
#  'price': 0.49,
#  'rating': 'Positive',
#  'release_date': 'Jun 17, 2021',
#  'reviews_count': '14',
#  'tags': 'Adventure,Indie,Singleplayer,Pixel '
#          'Graphics,2D,Arcade,Puzzle,Colorful,Atmospheric,Physics,3D '
#          'Platformer,Casual,Puzzle Platformer,3D,+',
#  'title': 'Mysterious Blocks 2',
#  'url': 'https://store.steampowered.com/app/1650080/Mysterious_Blocks_2/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1051290/ZIC__Zombies_in_City/?snr=1_7_7_151_150_2>
# {'category': ['Action Games'],
#  'developer': 'IO Games',
#  'platforms': ['win'],
#  'price': 4.99,
#  'rating': 'Positive',
#  'release_date': 'May 23, 2019',
#  'reviews_count': '31',
#  'tags': 'Shooter,FPS,Action,Zombies,Multiplayer,Co-op Campaign,Online '
#          'Co-Op,Co-op,First-Person,Adventure,Voxel,Post-apocalyptic,Action-Adventure,Story '
#          'Rich,Survival,Horror,Indie,Violent,Blood,Singleplayer,+',
#  'title': 'ZIC – Zombies in City',
#  'url': 'https://store.steampowered.com/app/1051290/ZIC__Zombies_in_City/?snr=1_7_7_151_150_2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/1593100/Earth_Marines/?snr=1_7_7_151_150_2>
# {'category': ['Action Games'],
#  'developer': 'HugePixel, Diedemor studio',
#  'platforms': ['win'],
#  'price': 10.99,
#  'rating': 'Positive',
#  'release_date': 'Jul 13, 2021',
#  'reviews_count': '15',
#  'tags': 'Action,Adventure,Shooter,2D,Top-Down,Isometric,Colorful,Military,Zombies,Violent,Gore,Indie,Dark,Post-apocalyptic,Singleplayer,+',
#  'title': 'Earth Marines',
#  'url': 'https://store.steampowered.com/app/1593100/Earth_Marines/?snr=1_7_7_151_150_2'}
# INFO:scrapy.core.engine:Closing spider (finished)
# INFO:scrapy.statscollectors:Dumping Scrapy stats:
# {'downloader/request_bytes': 29067,
#  'downloader/request_count': 58,
#  'downloader/request_method_count/GET': 58,
#  'downloader/response_bytes': 1527449,
#  'downloader/response_count': 58,
#  'downloader/response_status_count/200': 49,
#  'downloader/response_status_count/302': 9,
#  'elapsed_time_seconds': 6.923043,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 12, 7, 18, 19, 45, 943527),
#  'httpcompression/response_bytes': 9037951,
#  'httpcompression/response_count': 49,
#  'item_scraped_count': 47,
#  'memusage/max': 147218432,
#  'memusage/startup': 147218432,
#  'request_depth_max': 1,
#  'response_received_count': 49,
#  'scheduler/dequeued': 58,
#  'scheduler/dequeued/memory': 58,
#  'scheduler/enqueued': 58,
#  'scheduler/enqueued/memory': 58,
#  'start_time': datetime.datetime(2022, 12, 7, 18, 19, 39, 20484)}
# INFO:scrapy.core.engine:Spider closed (finished)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://store.steampowered.com/app/386640/Affected_Zone_Tactics/?snr=1_7_7_151_150_2>
# {'category': ['Strategy Games'],
#  'developer': 'Light Vision Interactive',
#  'platforms': ['win'],
#  'price': 'Бесплатно',
#  'rating': 'Mixed',
#  'release_date': 'Nov 17, 2015',
#  'reviews_count': '301',
#  'tags': 'Free to Play,Strategy,Massively '
#          'Multiplayer,Turn-Based,Tactical,Turn-Based Strategy,Turn-Based '
#          'Tactics,Isometric,Post-apocalyptic,Sci-fi,+',
#  'title': 'Affected Zone Tactics',
#  'url': 'https://store.steampowered.com/app/386640/Affected_Zone_Tactics/?snr=1_7_7_151_150_2'}
# INFO:scrapy.core.engine:Closing spider (finished)
# INFO:scrapy.statscollectors:Dumping Scrapy stats:
# {'downloader/request_bytes': 26566,
#  'downloader/request_count': 52,
#  'downloader/request_method_count/GET': 52,
#  'downloader/response_bytes': 1635416,
#  'downloader/response_count': 52,
#  'downloader/response_status_count/200': 52,
#  'elapsed_time_seconds': 7.075895,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 12, 7, 18, 19, 46, 4429),
#  'httpcompression/response_bytes': 9743511,
#  'httpcompression/response_count': 52,
#  'item_scraped_count': 50,
#  'memusage/max': 146952192,
#  'memusage/startup': 146952192,
#  'request_depth_max': 1,
#  'response_received_count': 52,
#  'scheduler/dequeued': 52,
#  'scheduler/dequeued/memory': 52,
#  'scheduler/enqueued': 52,
#  'scheduler/enqueued/memory': 52,
#  'start_time': datetime.datetime(2022, 12, 7, 18, 19, 38, 928534)}
# INFO:scrapy.core.engine:Spider closed (finished)
# INFO:scrapy.core.engine:Closing spider (finished)
# INFO:scrapy.statscollectors:Dumping Scrapy stats:
# {'downloader/request_bytes': 28398,
#  'downloader/request_count': 52,
#  'downloader/request_method_count/GET': 52,
#  'downloader/response_bytes': 1693461,
#  'downloader/response_count': 52,
#  'downloader/response_status_count/200': 52,
#  'elapsed_time_seconds': 7.057304,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 12, 7, 18, 19, 46, 23636),
#  'httpcompression/response_bytes': 10527663,
#  'httpcompression/response_count': 52,
#  'item_scraped_count': 50,
#  'memusage/max': 147218432,
#  'memusage/startup': 147218432,
#  'request_depth_max': 1,
#  'response_received_count': 52,
#  'scheduler/dequeued': 52,
#  'scheduler/dequeued/memory': 52,
#  'scheduler/enqueued': 52,
#  'scheduler/enqueued/memory': 52,
#  'start_time': datetime.datetime(2022, 12, 7, 18, 19, 38, 966332)}
# INFO:scrapy.core.engine:Spider closed (finished)

# %%
# убираем из результатов все, что было опубликовано до 2000 года
games = [game for game in games if game.get_release_year() > 2000]

# сохраняем в json файл
games = [game.to_dict() for game in games]
with open('games.json', 'w', encoding='utf-8') as f:
    json.dump(games, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ## Задание 2 (4 балла)

# %% [markdown]
# Создайте сайт с помощью Flask или Django. Будем делать конструктор резюме!
#
# Общая структура сайта:
#
# 1. Страничка с авторизацией и регистрацией
#
# 2. После авторизации, должна быть страница с формой, в которой необходимо заполнить форму (если пользователь уже заполнял форму, то в формы уже должен быть подгружен текст, который был заполнен, для этого должна быть отдельная кнопочка для сохранения в черновик)
#
# 3. Страница со скоинструированным резюме, который может быть превращен в PDF и выгружен (для этого можно использовать [pdfkit](https://pypi.org/project/pdfkit/))
#
# На всякий случай: пользователь не может посмотреть чужие резюме

# %% [markdown]
# ## Задание 3* (2 балла)
#
# Добавьте возможность загрузить картинку в резюме (для исходного задания это не требуется)
#
# Разверните приложение на Yandex.Cloud или на любом другом хосте (если знаете куда можно)

# %% [markdown]
# ## Задание 4 (3 балла)

# %% [markdown]
# Отрисуйте с помощью Dash или StreamLit данные из данного [датасета](https://www.kaggle.com/datasets/michaelbryantds/crimedata)
#
# Здесь необходимо провести самостоятельный анализ данных (можно даже в ноутбуке), в качестве результата необходим дашборд, внутри которого будет:
#
# * Не менее 5 селекторов
#
# * Не менее 5 различных графиков, которые показывали бы зависимость между преступлениями (на ваш выбор, там можно выбрать) и выбранными вами показателями
#
# Дашборд должен быть стилистически оформлен
